# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
x_data.describe(include= 'all')
# Out:
#                        record_id  ...  fuel_cost_per_mmbtu
# count                      29523  ...         29523.000000
# unique                     29523  ...                  NaN
# top     f1_fuel_1996_12_182_0_11  ...                  NaN
# freq                           1  ...                  NaN
# mean                         NaN  ...            19.304354
# std                          NaN  ...          2091.540939
# min                          NaN  ...           -41.501000
# 25%                          NaN  ...             1.940000
# 50%                          NaN  ...             4.127000
# 75%                          NaN  ...             7.745000
# max                          NaN  ...        359278.000000
#
# [11 rows x 11 columns]

# %%
sample_df = x_data.groupby('fuel_type_code_pudl','fuel_cost_per_unit_burned').reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9f7ad67e64ca> in <module>()
# ----> 1 sample_df = x_data.groupby('fuel_type_code_pudl','fuel_cost_per_unit_burned').reset_index(drop=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5797         if level is None and by is None:
#    5798             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5799         axis = self._get_axis_number(axis)
#    5800
#    5801         return groupby_generic.DataFrameGroupBy(
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15f419ed-d82b-4faa-a71c-9d75e74f4f7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15f419ed-d82b-4faa-a71c-9d75e74f4f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fuel_ferc1.csv to fuel_ferc1.csv

# %%
x_data = pd.read_csv('fuel_ferc1.csv')
x_data.to_excel
# Out:
# <bound method NDFrame.to_excel of                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]>

# %%
x_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
